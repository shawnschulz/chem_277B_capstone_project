# %%
# Chem 277B: Machine Learning Algorithms for
#            Molecular Sciences
#
# Date Created: 11/28/2024
# Last revisited: 12/13/2024


##################################
# FILE FOR RUNNING LSTM MODEL
##################################

'''can use lstm class to tune model parameters
and compare model output to actual data. Different metrics/graphs
and visualizations can be called from the utils file'''
# Out:
# 'can use lstm class to tune model parameters\nand compare model output to actual data. Different metrics/graphs\nand visualizations can be called from the utils file'

# %%
# imports 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nrsim_lstm import NRSIM_LSTM as lstm
import Archive.utils277b as utils

# %%
# read data from csv file

filepath="Simulation Data/Sim_no_Casualties"
data = pd.read_csv(filepath)


data.head(5)
# Out:
#    Time      pH   Hydrogen  Total Gas  Temperature     Pressure  \
# 0     0  11.000  50.000000  60.000000   500.000000  2100.000000
# 1     1  10.998  50.112998  60.112998   500.732703  2104.971916
# 2     2  10.996  50.225941  60.225941   501.463398  2109.930204
# 3     3  10.994  50.338517  60.338517   502.190083  2114.861274
# 4     4  10.992  50.450414  60.450414   502.910764  2119.751611
#
#    Radioactivity  Power  Reactor Safety  Injection of Air  \
# 0           10.0  100.0               0               NaN
# 1           10.0  100.0               0               NaN
# 2           10.0  100.0               0               NaN
# 3           10.0  100.0               0               NaN
# 4           10.0  100.0               0               NaN
#
#    Injection of Air Degree  Resin Overheat  Resin Overheat Degree  \
# 0                      NaN             NaN                    NaN
# 1                      NaN             NaN                    NaN
# 2                      NaN             NaN                    NaN
# 3                      NaN             NaN                    NaN
# 4                      NaN             NaN                    NaN
#
#    Fuel Element Failure  Fuel Element Failure Degree  Chemical Addition  \
# 0                   NaN                          NaN              False
# 1                   NaN                          NaN              False
# 2                   NaN                          NaN              False
# 3                   NaN                          NaN              False
# 4                   NaN                          NaN              False
#
#    Vent Gas
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
# setting up training data

n_past = 100
m_future = 50
features = 1

target_param = "Hydrogen"

# t represents time steps
t = data["Time"].values
t = t.reshape(len(t), 1)

# y(t) is the value of the target parameter at time t
y_t = data[target_param].values
y_t = y_t.reshape(len(y_t), 1)

scaler, y_t_normalized = utils.scale(y_t)

# creating training and testing data
X, y = utils.prep_lstm_data(y_t_normalized, n_past, m_future)



plt.plot(data["Time"].values, y_t)
plt.xlabel("Time")
plt.ylabel(f"{target_param}")
plt.title(f"Nuclear Reactor Simulation {target_param} vs Time")
plt.show()

# %%
# each shape[1] value corresponds to the number of points in the past 
# and number of points in the future for X and y, respectively

print(X.shape, y.shape)
# Out:
# (4172, 100, 1) (4172, 50, 1)

# %%
# train test splitting data

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False)

# %%
# model setup 

classify=False
npredfeatures = 1
# stacked lstm layers
neurons = [12, 6]
activation = "tanh"

# temporal params
n_past_timesteps = X.shape[1]
n_features = X.shape[2]
n_predicted_timesteps = y.shape[1]

# optimization + metrics
optimizer = "adam"
loss = "mse"
metrics =["mae", "mse"]

# convolutional layer
conv_layer = False
nfilters = 64  
conv_act = 'relu' 
pool_size = 2  

# dropout
dropout = 0



my_model = lstm(
    neurons,
    activation,
    n_past_timesteps,
    n_features,
    n_predicted_timesteps,
    npredfeatures,
    optimizer,
    loss,
    metrics,
    dropout,
    conv_layer,
    nfilters,
    conv_act,
    pool_size,
    classify
)

# %%
# fitting model on training data

n_epochs = 20
batch_size = 16


my_model.fit(X_train, y_train, nEpochs=n_epochs, nBatches=batch_size, val_split=0.2, verb=2, shuf=False)
# Out:
# Epoch 1/20
# 157/157 - 4s - 23ms/step - loss: 0.2235 - mae: 0.3890 - mse: 0.2235 - val_loss: 0.1022 - val_mae: 0.2775 - val_mse: 0.1022
# Epoch 2/20
# 157/157 - 2s - 15ms/step - loss: 0.0948 - mae: 0.2663 - mse: 0.0948 - val_loss: 0.0974 - val_mae: 0.2724 - val_mse: 0.0974
# Epoch 3/20
# 157/157 - 2s - 16ms/step - loss: 0.0932 - mae: 0.2646 - mse: 0.0932 - val_loss: 0.0972 - val_mae: 0.2721 - val_mse: 0.0972
# Epoch 4/20
# 157/157 - 2s - 16ms/step - loss: 0.0927 - mae: 0.2639 - mse: 0.0927 - val_loss: 0.0956 - val_mae: 0.2700 - val_mse: 0.0956
# Epoch 5/20
# 157/157 - 2s - 14ms/step - loss: 0.0930 - mae: 0.2643 - mse: 0.0930 - val_loss: 0.0972 - val_mae: 0.2722 - val_mse: 0.0972
# Epoch 6/20
# 157/157 - 2s - 14ms/step - loss: 0.0930 - mae: 0.2643 - mse: 0.0930 - val_loss: 0.0970 - val_mae: 0.2719 - val_mse: 0.0970
# Epoch 7/20
# 157/157 - 2s - 14ms/step - loss: 0.0928 - mae: 0.2641 - mse: 0.0928 - val_loss: 0.0968 - val_mae: 0.2716 - val_mse: 0.0968
# Epoch 8/20
# 157/157 - 2s - 15ms/step - loss: 0.0926 - mae: 0.2638 - mse: 0.0926 - val_loss: 0.0965 - val_mae: 0.2713 - val_mse: 0.0965
# Epoch 9/20
# 157/157 - 2s - 15ms/step - loss: 0.0923 - mae: 0.2633 - mse: 0.0923 - val_loss: 0.0961 - val_mae: 0.2706 - val_mse: 0.0961
# Epoch 10/20
# 157/157 - 2s - 15ms/step - loss: 0.0900 - mae: 0.2599 - mse: 0.0900 - val_loss: 0.0855 - val_mae: 0.2548 - val_mse: 0.0855
# Epoch 11/20
# 157/157 - 2s - 14ms/step - loss: 0.0916 - mae: 0.2619 - mse: 0.0916 - val_loss: 0.0953 - val_mae: 0.2695 - val_mse: 0.0953
# Epoch 12/20
# 157/157 - 2s - 15ms/step - loss: 0.0909 - mae: 0.2614 - mse: 0.0909 - val_loss: 0.0942 - val_mae: 0.2680 - val_mse: 0.0942
# Epoch 13/20
# 157/157 - 2s - 15ms/step - loss: 0.0896 - mae: 0.2596 - mse: 0.0896 - val_loss: 0.0916 - val_mae: 0.2644 - val_mse: 0.0916
# Epoch 14/20
# 157/157 - 2s - 14ms/step - loss: 0.0863 - mae: 0.2548 - mse: 0.0863 - val_loss: 0.0856 - val_mae: 0.2550 - val_mse: 0.0856
# Epoch 15/20
# 157/157 - 2s - 14ms/step - loss: 0.0732 - mae: 0.2330 - mse: 0.0732 - val_loss: 0.0614 - val_mae: 0.2109 - val_mse: 0.0614
# Epoch 16/20
# 157/157 - 2s - 14ms/step - loss: 0.0596 - mae: 0.2070 - mse: 0.0596 - val_loss: 0.0471 - val_mae: 0.1839 - val_mse: 0.0471
# Epoch 17/20
# 157/157 - 2s - 14ms/step - loss: 0.0445 - mae: 0.1777 - mse: 0.0445 - val_loss: 0.0379 - val_mae: 0.1631 - val_mse: 0.0379
# Epoch 18/20
# 157/157 - 2s - 14ms/step - loss: 0.0379 - mae: 0.1612 - mse: 0.0379 - val_loss: 0.0314 - val_mae: 0.1457 - val_mse: 0.0314
# Epoch 19/20
# 157/157 - 2s - 14ms/step - loss: 0.0324 - mae: 0.1460 - mse: 0.0324 - val_loss: 0.0254 - val_mae: 0.1278 - val_mse: 0.0254
# Epoch 20/20
# 157/157 - 2s - 14ms/step - loss: 0.0264 - mae: 0.1275 - mse: 0.0264 - val_loss: 0.0204 - val_mae: 0.1109 - val_mse: 0.0204

# %%
# model history

out = my_model.get_model().history

# %%
# plotting loss during training
plt.plot(out.history['loss'])
plt.plot(out.history['val_loss'])
plt.title('model loss')
plt.ylabel('mean squared error')
plt.xlabel('epoch')
plt.legend(['train', 'val_loss'], loc = 'upper left')
#plt.savefig('training loss.pdf')
plt.show()

# %%
# predicting + transforming normalized data 
y_pred_normalized = my_model.predict(X_test)
back  = y_pred_normalized.shape[0]
y_pred = scaler.inverse_transform(y_pred_normalized)

# setting bounds for graph
y_min = min(np.min(y_pred), np.min(y_t)) 
y_max = max(np.max(y_pred), np.max(y_t))
plt.ylim(y_min - 0.25, y_max + 0.25)

# plot
plt.plot(t, y_t)
plt.plot(t[-back:], y_pred[:, m_future-1])
plt.legend(['actual data', 'prediction'])
plt.fill_between([t[-back,0], t[-1,0]], y_min, y_max , color = 'k', alpha = 0.1)
plt.plot([t[-back,0], t[-back,0]], [y_min, y_max ], 'k-')
plt.xlabel("Time")
plt.ylabel(f"{target_param}")
plt.title(f"Nuclear Reactor Simulation {target_param} vs Time")
plt.show()
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
